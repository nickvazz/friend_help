# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline

t = np.linspace(0, 1, 100, endpoint=False)
y = signal.square(2 * np.pi * 5 * t)

plt.plot(t, y)
plt.ylim(-2, 2)
plt.show()


noise = np.random.random_sample(100) * .1
y_noise = y + noise
# Out:
# 100

# %%
r = []
window = 10
for i in range(len(t)):
    try:
        tempy = y[i:i+window]
        fity = [-1]*window
    #     print fity
        r.append(r2_score(tempy,fity))
    except:
        pass
plt.plot(t[window-1:],r)
plt.plot(t,y)
plt.ylim(-2,2)
plt.show()
# Out:
# (-2, 2)

# %%
r = []
window = 10
for i in range(len(t)):
    try:
        tempy = y[i:i+window]
        fity = [-1]*window
    #     print fity
        r.append(r2_score(tempy,fity))
    except:
        pass
plt.plot(t[window-1:],r)
plt.plot(t,y)
plt.ylim(-2,2)
plt.show()
